# %% [markdown]
# ### Read the input image

# %%
# import the needed libraries
import tensorflow as tf
import tensorflow.contrib.tensorrt as trt # must import this although we will not use it explicitly
from tensorflow.python.platform import gfile
from PIL import Image
import numpy as np
import time
from matplotlib import pyplot as plt

# read the testing images (only for example)
img1= Image.open("dataset/mnist/testing/0/img_108.jpg")
img2= Image.open("dataset/mnist/testing/1/img_0.jpg")
img1 = np.asarray(img1)
img2 = np.asarray(img2)
input_img = np.concatenate((img1.reshape((1, 28, 28, 1)), 
                            img2.reshape((1, 28, 28, 1))), 
                           axis=0)

# %% [markdown]
# ### Function to read ".pb" model (TensorRT model is stored in ".pb")

# %%
# function to read a ".pb" model 
# (can be used to read frozen model or TensorRT model)
def read_pb_graph(model):
  with gfile.FastGFile(model,'rb') as f:
    graph_def = tf.GraphDef()
    graph_def.ParseFromString(f.read())
  return graph_def

# %% [markdown]
# ### Perform inference using TensorRT model

# %%
# variable
TENSORRT_MODEL_PATH = './model/TensorRT_model.pb'

graph = tf.Graph()
with graph.as_default():
    with tf.Session(config=tf.ConfigProto(gpu_options=tf.GPUOptions(per_process_gpu_memory_fraction=0.50))) as sess:
        # read TensorRT model
        trt_graph = read_pb_graph(TENSORRT_MODEL_PATH)

        # obtain the corresponding input-output tensor
        tf.import_graph_def(trt_graph, name='')
        input = sess.graph.get_tensor_by_name('input_tensor_input:0')
        output = sess.graph.get_tensor_by_name('output_tensor/Softmax:0')

        # in this case, it demonstrates to perform inference for 50 times
        total_time = 0; n_time_inference = 50
        out_pred = sess.run(output, feed_dict={input: input_img})
        for i in range(n_time_inference):
            t1 = time.time()
            out_pred = sess.run(output, feed_dict={input: input_img})
            t2 = time.time()
            delta_time = t2 - t1
            total_time += delta_time
            print("needed time in inference-" + str(i) + ": ", delta_time)
        avg_time_tensorRT = total_time / n_time_inference
        print("average inference time: ", avg_time_tensorRT)
# Out:
# WARNING:tensorflow:From <ipython-input-2-a1064865cc5f>:4: FastGFile.__init__ (from tensorflow.python.platform.gfile) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.gfile.GFile.
# needed time in inference-0:  0.0382843017578125
# needed time in inference-1:  0.03830695152282715
# needed time in inference-2:  0.03839921951293945
# needed time in inference-3:  0.03428769111633301
# needed time in inference-4:  0.035218238830566406
# needed time in inference-5:  0.03542971611022949
# needed time in inference-6:  0.032062530517578125
# needed time in inference-7:  0.036420345306396484
# needed time in inference-8:  0.03457975387573242
# needed time in inference-9:  0.03524041175842285
# needed time in inference-10:  0.03532910346984863
# needed time in inference-11:  0.035097599029541016
# needed time in inference-12:  0.031996965408325195
# needed time in inference-13:  0.0362248420715332
# needed time in inference-14:  0.0322115421295166
# needed time in inference-15:  0.032035112380981445
# needed time in inference-16:  0.0321803092956543
# needed time in inference-17:  0.03584623336791992
# needed time in inference-18:  0.03628730773925781
# needed time in inference-19:  0.04030132293701172
# needed time in inference-20:  0.03694963455200195
# needed time in inference-21:  0.03555917739868164
# needed time in inference-22:  0.035234689712524414
# needed time in inference-23:  0.03522372245788574
# needed time in inference-24:  0.037425994873046875
# needed time in inference-25:  0.0346827507019043
# needed time in inference-26:  0.03567862510681152
# needed time in inference-27:  0.03765439987182617
# needed time in inference-28:  0.03153705596923828
# needed time in inference-29:  0.03539729118347168
# needed time in inference-30:  0.032096147537231445
# needed time in inference-31:  0.04018092155456543
# needed time in inference-32:  0.033637046813964844
# needed time in inference-33:  0.03524351119995117
# needed time in inference-34:  0.035198211669921875
# needed time in inference-35:  0.0353856086730957
# needed time in inference-36:  0.03203153610229492
# needed time in inference-37:  0.03982830047607422
# needed time in inference-38:  0.03276205062866211
# needed time in inference-39:  0.03555560111999512
# needed time in inference-40:  0.035706520080566406
# needed time in inference-41:  0.03537893295288086
# needed time in inference-42:  0.03521990776062012
# needed time in inference-43:  0.03535962104797363
# needed time in inference-44:  0.03566265106201172
# needed time in inference-45:  0.035748958587646484
# needed time in inference-46:  0.03554534912109375
# needed time in inference-47:  0.035806894302368164
# needed time in inference-48:  0.03331780433654785
# needed time in inference-49:  0.04301881790161133
# average inference time:  0.03547534465789795

# %% [markdown]
# ### Perform inference using the original tensorflow model

# %%
# variable
FROZEN_MODEL_PATH = './model/frozen_model.pb'

graph = tf.Graph()
with graph.as_default():
    with tf.Session() as sess:
        # read TensorRT model
        frozen_graph = read_pb_graph(FROZEN_MODEL_PATH)

        # obtain the corresponding input-output tensor
        tf.import_graph_def(frozen_graph, name='')
        input = sess.graph.get_tensor_by_name('input_tensor_input:0')
        output = sess.graph.get_tensor_by_name('output_tensor/Softmax:0')

        # in this case, it demonstrates to perform inference for 50 times
        total_time = 0; n_time_inference = 50
        out_pred = sess.run(output, feed_dict={input: input_img})
        for i in range(n_time_inference):
            t1 = time.time()
            out_pred = sess.run(output, feed_dict={input: input_img})
            t2 = time.time()
            delta_time = t2 - t1
            total_time += delta_time
            print("needed time in inference-" + str(i) + ": ", delta_time)
        avg_time_original_model = total_time / n_time_inference
        print("average inference time: ", avg_time_original_model)
        print("TensorRT improvement compared to the original model:", avg_time_original_model/avg_time_tensorRT)
# Out:
# needed time in inference-0:  0.12877154350280762
# needed time in inference-1:  0.12258100509643555
# needed time in inference-2:  0.12850093841552734
# needed time in inference-3:  0.12608838081359863
# needed time in inference-4:  0.13204193115234375
# needed time in inference-5:  0.12585878372192383
# needed time in inference-6:  0.13083410263061523
# needed time in inference-7:  0.12645387649536133
# needed time in inference-8:  0.13179230690002441
# needed time in inference-9:  0.12787175178527832
# needed time in inference-10:  0.12690997123718262
# needed time in inference-11:  0.1282658576965332
# needed time in inference-12:  0.1314239501953125
# needed time in inference-13:  0.1252601146697998
# needed time in inference-14:  0.1307995319366455
# needed time in inference-15:  0.1278383731842041
# needed time in inference-16:  0.13188719749450684
# needed time in inference-17:  0.12649893760681152
# needed time in inference-18:  0.12932467460632324
# needed time in inference-19:  0.12459063529968262
# needed time in inference-20:  0.12936186790466309
# needed time in inference-21:  0.1256704330444336
# needed time in inference-22:  0.13037443161010742
# needed time in inference-23:  0.12526798248291016
# needed time in inference-24:  0.1307518482208252
# needed time in inference-25:  0.13167810440063477
# needed time in inference-26:  0.14519143104553223
# needed time in inference-27:  0.13524270057678223
# needed time in inference-28:  0.14722084999084473
# needed time in inference-29:  0.1385960578918457
# needed time in inference-30:  0.13965320587158203
# needed time in inference-31:  0.13946962356567383
# needed time in inference-32:  0.1314990520477295
# needed time in inference-33:  0.12590932846069336
# needed time in inference-34:  0.13366198539733887
# needed time in inference-35:  0.1493973731994629
# needed time in inference-36:  0.13354825973510742
# needed time in inference-37:  0.1321091651916504
# needed time in inference-38:  0.14974617958068848
# needed time in inference-39:  0.13389992713928223
# needed time in inference-40:  0.12975215911865234
# needed time in inference-41:  0.12545442581176758
# needed time in inference-42:  0.13192439079284668
# needed time in inference-43:  0.12437176704406738
# needed time in inference-44:  0.12926959991455078
# needed time in inference-45:  0.1280064582824707
# needed time in inference-46:  0.1318497657775879
# needed time in inference-47:  0.1270589828491211
# needed time in inference-48:  0.131195068359375
# needed time in inference-49:  0.12352395057678223
# average inference time:  0.13108500480651855
# TensorRT improvement compared to the original model: 3.695101656393205

# %% [markdown]
# ### Plot the prediction result

# %%
# plot the prediction output
plt.figure('img 1')
plt.imshow(img1, cmap='gray')
plt.title('pred:' + str(np.argmax(out_pred[0])), fontsize=22)

plt.figure('img 2')
plt.imshow(img2, cmap='gray')
plt.title('pred:' + str(np.argmax(out_pred[1])), fontsize=22)
plt.show()
