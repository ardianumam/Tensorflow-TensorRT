# %% [markdown]
# ### Convert Keras model to Tensorflow model

# %%
# import the needed libraries
import tensorflow as tf
tf.keras.backend.set_learning_phase(0) #use this if we have batch norm layer in our network
from tensorflow.keras.models import load_model

# path we wanna save our converted TF-model
MODEL_PATH = "./model/tensorflow/model1"

# load the Keras model
model = load_model('./model/modelLeNet5.h5')

# save the model to Tensorflow model
saver = tf.train.Saver()
sess = tf.keras.backend.get_session()
save_path = saver.save(sess, MODEL_PATH)

print("Keras model is successfully converted to TF model in "+MODEL_PATH)
# Out:
# ---------------------------------------------------------------------------
# PermissionDeniedError                     Traceback (most recent call last)
# ~/.conda/envs/TF1120_GPU/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#
# ~/.conda/envs/TF1120_GPU/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#
# ~/.conda/envs/TF1120_GPU/lib/python3.5/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#
# PermissionDeniedError: ./model/tensorflow/model1.data-00000-of-00001.tempstate1458345464240017155; Permission denied
# 	 [[{{node save/SaveV2}} = SaveV2[dtypes=[DT_FLOAT, DT_INT64, DT_FLOAT, DT_FLOAT, DT_FLOAT, ..., DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save/Const_0_0, save/SaveV2/tensor_names, save/SaveV2/shape_and_slices, SGD/decay/Read/ReadVariableOp/_155, SGD/iterations/Read/ReadVariableOp/_157, SGD/lr/Read/ReadVariableOp/_159, SGD/momentum/Read/ReadVariableOp/_161, conv2d/bias/Read/ReadVariableOp/_163, conv2d/kernel/Read/ReadVariableOp/_165, conv2d_1/bias/Read/ReadVariableOp/_167, conv2d_1/kernel/Read/ReadVariableOp/_169, dense/bias/Read/ReadVariableOp/_171, dense/kernel/Read/ReadVariableOp/_173, input_tensor/bias/Read/ReadVariableOp/_175, input_tensor/kernel/Read/ReadVariableOp/_177, output_tensor/bias/Read/ReadVariableOp/_179, output_tensor/kernel/Read/ReadVariableOp/_181, training/SGD/Variable/Read/ReadVariableOp/_183, training/SGD/Variable_1/Read/ReadVariableOp/_185, training/SGD/Variable_2/Read/ReadVariableOp/_187, training/SGD/Variable_3/Read/ReadVariableOp/_189, training/SGD/Variable_4/Read/ReadVariableOp/_191, training/SGD/Variable_5/Read/ReadVariableOp/_193, training/SGD/Variable_6/Read/ReadVariableOp/_195, training/SGD/Variable_7/Read/ReadVariableOp/_197, training/SGD/Variable_8/Read/ReadVariableOp/_199, training/SGD/Variable_9/Read/ReadVariableOp/_201)]]
#
# During handling of the above exception, another exception occurred:
#
# PermissionDeniedError                     Traceback (most recent call last)
# <ipython-input-1-ea323c614868> in <module>()
#      13 saver = tf.train.Saver()
#      14 sess = tf.keras.backend.get_session()
# ---> 15 save_path = saver.save(sess, MODEL_PATH)
#      16
#      17 print("Keras model is successfully converted to TF model in "+MODEL_PATH)
#
# ~/.conda/envs/TF1120_GPU/lib/python3.5/site-packages/tensorflow/python/training/saver.py in save(self, sess, save_path, global_step, latest_filename, meta_graph_suffix, write_meta_graph, write_state, strip_default_attrs)
#    1439           model_checkpoint_path = sess.run(
#    1440               self.saver_def.save_tensor_name,
# -> 1441               {self.saver_def.filename_tensor_name: checkpoint_file})
#    1442
#    1443         model_checkpoint_path = compat.as_str(model_checkpoint_path)
#
# ~/.conda/envs/TF1120_GPU/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/.conda/envs/TF1120_GPU/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# ~/.conda/envs/TF1120_GPU/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/.conda/envs/TF1120_GPU/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1346           pass
#    1347       message = error_interpolation.interpolate(message, self._graph)
# -> 1348       raise type(e)(node_def, op, message)
#    1349
#    1350   def _extend_graph(self):
#
# PermissionDeniedError: ./model/tensorflow/model1.data-00000-of-00001.tempstate1458345464240017155; Permission denied
# 	 [[node save/SaveV2 (defined at <ipython-input-1-ea323c614868>:13)  = SaveV2[dtypes=[DT_FLOAT, DT_INT64, DT_FLOAT, DT_FLOAT, DT_FLOAT, ..., DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save/Const_0_0, save/SaveV2/tensor_names, save/SaveV2/shape_and_slices, SGD/decay/Read/ReadVariableOp/_155, SGD/iterations/Read/ReadVariableOp/_157, SGD/lr/Read/ReadVariableOp/_159, SGD/momentum/Read/ReadVariableOp/_161, conv2d/bias/Read/ReadVariableOp/_163, conv2d/kernel/Read/ReadVariableOp/_165, conv2d_1/bias/Read/ReadVariableOp/_167, conv2d_1/kernel/Read/ReadVariableOp/_169, dense/bias/Read/ReadVariableOp/_171, dense/kernel/Read/ReadVariableOp/_173, input_tensor/bias/Read/ReadVariableOp/_175, input_tensor/kernel/Read/ReadVariableOp/_177, output_tensor/bias/Read/ReadVariableOp/_179, output_tensor/kernel/Read/ReadVariableOp/_181, training/SGD/Variable/Read/ReadVariableOp/_183, training/SGD/Variable_1/Read/ReadVariableOp/_185, training/SGD/Variable_2/Read/ReadVariableOp/_187, training/SGD/Variable_3/Read/ReadVariableOp/_189, training/SGD/Variable_4/Read/ReadVariableOp/_191, training/SGD/Variable_5/Read/ReadVariableOp/_193, training/SGD/Variable_6/Read/ReadVariableOp/_195, training/SGD/Variable_7/Read/ReadVariableOp/_197, training/SGD/Variable_8/Read/ReadVariableOp/_199, training/SGD/Variable_9/Read/ReadVariableOp/_201)]]
#
# Caused by op 'save/SaveV2', defined at:
#   File "/home/cvrc/.conda/envs/TF1120_GPU/lib/python3.5/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/cvrc/.conda/envs/TF1120_GPU/lib/python3.5/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/cvrc/.conda/envs/TF1120_GPU/lib/python3.5/site-packages/ipykernel/__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "/home/cvrc/.conda/envs/TF1120_GPU/lib/python3.5/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/cvrc/.conda/envs/TF1120_GPU/lib/python3.5/site-packages/ipykernel/kernelapp.py", line 499, in start
#     self.io_loop.start()
#   File "/home/cvrc/.conda/envs/TF1120_GPU/lib/python3.5/site-packages/tornado/platform/asyncio.py", line 132, in start
#     self.asyncio_loop.run_forever()
#   File "/home/cvrc/.conda/envs/TF1120_GPU/lib/python3.5/asyncio/base_events.py", line 421, in run_forever
#     self._run_once()
#   File "/home/cvrc/.conda/envs/TF1120_GPU/lib/python3.5/asyncio/base_events.py", line 1425, in _run_once
#     handle._run()
#   File "/home/cvrc/.conda/envs/TF1120_GPU/lib/python3.5/asyncio/events.py", line 127, in _run
#     self._callback(*self._args)
#   File "/home/cvrc/.conda/envs/TF1120_GPU/lib/python3.5/site-packages/tornado/platform/asyncio.py", line 122, in _handle_events
#     handler_func(fileobj, events)
#   File "/home/cvrc/.conda/envs/TF1120_GPU/lib/python3.5/site-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/cvrc/.conda/envs/TF1120_GPU/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/home/cvrc/.conda/envs/TF1120_GPU/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/cvrc/.conda/envs/TF1120_GPU/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/cvrc/.conda/envs/TF1120_GPU/lib/python3.5/site-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/cvrc/.conda/envs/TF1120_GPU/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/cvrc/.conda/envs/TF1120_GPU/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/cvrc/.conda/envs/TF1120_GPU/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/cvrc/.conda/envs/TF1120_GPU/lib/python3.5/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/cvrc/.conda/envs/TF1120_GPU/lib/python3.5/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/cvrc/.conda/envs/TF1120_GPU/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/home/cvrc/.conda/envs/TF1120_GPU/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/cvrc/.conda/envs/TF1120_GPU/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2901, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/cvrc/.conda/envs/TF1120_GPU/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2961, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-ea323c614868>", line 13, in <module>
#     saver = tf.train.Saver()
#   File "/home/cvrc/.conda/envs/TF1120_GPU/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 1102, in __init__
#     self.build()
#   File "/home/cvrc/.conda/envs/TF1120_GPU/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 1114, in build
#     self._build(self._filename, build_save=True, build_restore=True)
#   File "/home/cvrc/.conda/envs/TF1120_GPU/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 1151, in _build
#     build_save=build_save, build_restore=build_restore)
#   File "/home/cvrc/.conda/envs/TF1120_GPU/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 792, in _build_internal
#     save_tensor = self._AddSaveOps(filename_tensor, saveables)
#   File "/home/cvrc/.conda/envs/TF1120_GPU/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 284, in _AddSaveOps
#     save = self.save_op(filename_tensor, saveables)
#   File "/home/cvrc/.conda/envs/TF1120_GPU/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 202, in save_op
#     tensors)
#   File "/home/cvrc/.conda/envs/TF1120_GPU/lib/python3.5/site-packages/tensorflow/python/ops/gen_io_ops.py", line 1690, in save_v2
#     shape_and_slices=shape_and_slices, tensors=tensors, name=name)
#   File "/home/cvrc/.conda/envs/TF1120_GPU/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "/home/cvrc/.conda/envs/TF1120_GPU/lib/python3.5/site-packages/tensorflow/python/util/deprecation.py", line 488, in new_func
#     return func(*args, **kwargs)
#   File "/home/cvrc/.conda/envs/TF1120_GPU/lib/python3.5/site-packages/tensorflow/python/framework/ops.py", line 3274, in create_op
#     op_def=op_def)
#   File "/home/cvrc/.conda/envs/TF1120_GPU/lib/python3.5/site-packages/tensorflow/python/framework/ops.py", line 1770, in __init__
#     self._traceback = tf_stack.extract_stack()
#
# PermissionDeniedError (see above for traceback): ./model/tensorflow/model1.data-00000-of-00001.tempstate1458345464240017155; Permission denied
# 	 [[node save/SaveV2 (defined at <ipython-input-1-ea323c614868>:13)  = SaveV2[dtypes=[DT_FLOAT, DT_INT64, DT_FLOAT, DT_FLOAT, DT_FLOAT, ..., DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save/Const_0_0, save/SaveV2/tensor_names, save/SaveV2/shape_and_slices, SGD/decay/Read/ReadVariableOp/_155, SGD/iterations/Read/ReadVariableOp/_157, SGD/lr/Read/ReadVariableOp/_159, SGD/momentum/Read/ReadVariableOp/_161, conv2d/bias/Read/ReadVariableOp/_163, conv2d/kernel/Read/ReadVariableOp/_165, conv2d_1/bias/Read/ReadVariableOp/_167, conv2d_1/kernel/Read/ReadVariableOp/_169, dense/bias/Read/ReadVariableOp/_171, dense/kernel/Read/ReadVariableOp/_173, input_tensor/bias/Read/ReadVariableOp/_175, input_tensor/kernel/Read/ReadVariableOp/_177, output_tensor/bias/Read/ReadVariableOp/_179, output_tensor/kernel/Read/ReadVariableOp/_181, training/SGD/Variable/Read/ReadVariableOp/_183, training/SGD/Variable_1/Read/ReadVariableOp/_185, training/SGD/Variable_2/Read/ReadVariableOp/_187, training/SGD/Variable_3/Read/ReadVariableOp/_189, training/SGD/Variable_4/Read/ReadVariableOp/_191, training/SGD/Variable_5/Read/ReadVariableOp/_193, training/SGD/Variable_6/Read/ReadVariableOp/_195, training/SGD/Variable_7/Read/ReadVariableOp/_197, training/SGD/Variable_8/Read/ReadVariableOp/_199, training/SGD/Variable_9/Read/ReadVariableOp/_201)]]

# %% [markdown]
# ### Keras to TensorRT
# ![alt text](pictures/Keras_to_TensorRT.png)
#
# ### Tensorflow to TensorRT
# ![alt text](pictures/tf-trt_workflow.png)
